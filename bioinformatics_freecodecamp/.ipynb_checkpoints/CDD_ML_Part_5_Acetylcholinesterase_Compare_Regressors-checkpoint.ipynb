# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 5] Comparing Regressors**
#
# Chanin Nantasenamat
#
# ['Data Professor' YouTube channel](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life data science project that you can include in your data science portfolio. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In Part 5, we will be comparing several ML algorithms for build regression models of acetylcholinesterase inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.16-py2.py3-none-any.whl.metadata (13 kB)
# Collecting click (from lazypredict)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: scikit-learn in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (1.7.2)
# Requirement already satisfied: pandas in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (2.3.3)
# Collecting tqdm (from lazypredict)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: joblib in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (1.5.2)
# Collecting lightgbm (from lazypredict)
#   Downloading lightgbm-4.6.0-py3-none-manylinux_2_28_x86_64.whl.metadata (17 kB)
# Collecting xgboost (from lazypredict)
#   Downloading xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting pytest-runner (from lazypredict)
#   Downloading pytest_runner-6.0.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting mlflow>=2.0.0 (from lazypredict)
#   Downloading mlflow-3.6.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-skinny==3.6.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading mlflow_skinny-3.6.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.6.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading mlflow_tracing-3.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow>=2.0.0->lazypredict)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting Flask<4 (from mlflow>=2.0.0->lazypredict)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow>=2.0.0->lazypredict)
#   Downloading alembic-1.17.2-py3-none-any.whl.metadata (7.2 kB)
# Collecting cryptography<47,>=43.0.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading cryptography-46.0.3-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow>=2.0.0->lazypredict)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow>=2.0.0->lazypredict)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting huey<3,>=2.5.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading huey-2.5.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: matplotlib<4 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (3.10.6)
# Requirement already satisfied: numpy<3 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (2.2.5)
# Collecting pyarrow<23,>=4.0.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading pyarrow-22.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: scipy<2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (2.0.43)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting cloudpickle<4 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading databricks_sdk-0.73.0-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading fastapi-0.121.3-py3-none-any.whl.metadata (30 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (25.0)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pydantic<3,>=2.0.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Collecting python-dotenv<2,>=0.19.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (2.32.5)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (4.15.0)
# Collecting uvicorn<1 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazypredict)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: tomli in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazypredict) (2.2.1)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from cryptography<47,>=43.0.0->mlflow>=2.0.0->lazypredict) (2.0.0)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->lazypredict) (2.5.0)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow>=2.0.0->lazypredict)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow>=2.0.0->lazypredict)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.0.2)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow>=2.0.0->lazypredict)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow>=2.0.0->lazypredict)
#   Downloading graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow>=2.0.0->lazypredict)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (2.9.0.post0)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (3.2.0)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from pandas->lazypredict) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from pandas->lazypredict) (2025.2)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow>=2.0.0->lazypredict) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (2025.10.5)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: greenlet>=1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.0.0->lazypredict) (3.2.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (4.10.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (1.3.0)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow>=2.0.0->lazypredict) (2.23)
# Collecting nvidia-nccl-cu12 (from xgboost->lazypredict)
#   Downloading nvidia_nccl_cu12-2.28.9-py3-none-manylinux_2_18_x86_64.whl.metadata (2.0 kB)
# Downloading lazypredict-0.2.16-py2.py3-none-any.whl (14 kB)
# Downloading mlflow-3.6.0-py3-none-any.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 13.6 MB/s  0:00:00m0:00:0100:01
# Downloading mlflow_skinny-3.6.0-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 14.5 MB/s  0:00:00
# Downloading mlflow_tracing-3.6.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.2 MB/s  0:00:00
# Downloading alembic-1.17.2-py3-none-any.whl (248 kB)
# Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading cryptography-46.0.3-cp38-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 14.4 MB/s  0:00:00 eta 0:00:01
# Downloading databricks_sdk-0.73.0-py3-none-any.whl (753 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.9/753.9 kB 8.2 MB/s  0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.121.3-py3-none-any.whl (109 kB)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading huey-2.5.4-py3-none-any.whl (76 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Downloading pyarrow-22.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (47.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 14.0 MB/s  0:00:03m0:00:0100:01
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.1 MB/s  0:00:00
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading lightgbm-4.6.0-py3-none-manylinux_2_28_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 11.8 MB/s  0:00:00 eta 0:00:01
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading pytest_runner-6.0.1-py3-none-any.whl (7.2 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl (115.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 MB 14.6 MB/s  0:00:07m0:00:0100:01
# Downloading nvidia_nccl_cu12-2.28.9-py3-none-manylinux_2_18_x86_64.whl (296.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.8/296.8 MB 14.0 MB/s  0:00:21m0:00:0100:01
# Installing collected packages: huey, zipp, werkzeug, typing-inspection, tqdm, sqlparse, smmap, python-dotenv, pytest-runner, pydantic-core, pyasn1, pyarrow, protobuf, nvidia-nccl-cu12, Mako, itsdangerous, gunicorn, graphql-core, cloudpickle, click, cachetools, blinker, annotated-types, annotated-doc, xgboost, uvicorn, starlette, rsa, pydantic, pyasn1-modules, opentelemetry-proto, lightgbm, importlib_metadata, graphql-relay, gitdb, Flask, docker, cryptography, alembic, opentelemetry-api, graphene, google-auth, gitpython, Flask-CORS, fastapi, opentelemetry-semantic-conventions, databricks-sdk, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow, lazypredict
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52/52 [lazypredict] [mlflow]skinny]]c-conventions]
# Successfully installed Flask-3.1.2 Flask-CORS-6.0.1 Mako-1.3.10 alembic-1.17.2 annotated-doc-0.0.4 annotated-types-0.7.0 blinker-1.9.0 cachetools-6.2.2 click-8.3.1 cloudpickle-3.1.2 cryptography-46.0.3 databricks-sdk-0.73.0 docker-7.1.0 fastapi-0.121.3 gitdb-4.0.12 gitpython-3.1.45 google-auth-2.43.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 gunicorn-23.0.0 huey-2.5.4 importlib_metadata-8.7.0 itsdangerous-2.2.0 lazypredict-0.2.16 lightgbm-4.6.0 mlflow-3.6.0 mlflow-skinny-3.6.0 mlflow-tracing-3.6.0 nvidia-nccl-cu12-2.28.9 opentelemetry-api-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 protobuf-6.33.1 pyarrow-22.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.12.4 pydantic-core-2.41.5 pytest-runner-6.0.1 python-dotenv-1.2.1 rsa-4.9.1 smmap-5.0.2 sqlparse-0.5.3 starlette-0.50.0 tqdm-4.67.1 typing-inspection-0.4.2 uvicorn-0.38.0 werkzeug-3.1.3 xgboost-3.1.1 zipp-3.23.0

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor
import tqdm
tqdm.notebook.tqdm = tqdm.tqdm

# %% [markdown]
# ## **2. Load the data set**

# %%
! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Out:
# --2025-11-19 12:28:57--  https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv [following]
# --2025-11-19 12:28:58--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8363909 (8.0M) [text/plain]
# Saving to: ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv.2’
#
# acetylcholinesteras 100%[===================>]   7.98M  13.5MB/s    in 0.6s
#
# 2025-11-19 12:28:59 (13.5 MB/s) - ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv.2’ saved [8363909/8363909]

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (4695, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008036 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001098 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreeRegressor                           0.86       0.86  0.57        0.12
# DecisionTreeRegressor                        0.86       0.86  0.57        0.13
# ExtraTreesRegressor                          0.86       0.86  0.57        6.99
# GaussianProcessRegressor                     0.86       0.86  0.57        4.33
# RandomForestRegressor                        0.82       0.83  0.64        4.65
# XGBRegressor                                 0.82       0.83  0.65        6.62
# BaggingRegressor                             0.80       0.81  0.67        0.59
# MLPRegressor                                 0.76       0.77  0.75        3.79
# HistGradientBoostingRegressor                0.67       0.69  0.87        0.83
# LGBMRegressor                                0.65       0.67  0.90        0.27
# KNeighborsRegressor                          0.63       0.65  0.92        0.15
# SVR                                          0.56       0.58  1.01        2.48
# NuSVR                                        0.55       0.57  1.02        1.90
# GradientBoostingRegressor                    0.44       0.46  1.14        1.79
# TransformedTargetRegressor                   0.31       0.33  1.27        0.18
# LinearRegression                             0.31       0.33  1.27        0.07
# Ridge                                        0.31       0.33  1.27        0.17
# LassoCV                                      0.30       0.33  1.27        2.03
# ElasticNetCV                                 0.30       0.33  1.27        2.00
# RidgeCV                                      0.30       0.33  1.27        0.07
# SGDRegressor                                 0.30       0.32  1.28        0.13
# BayesianRidge                                0.29       0.32  1.28        0.24
# HuberRegressor                               0.29       0.31  1.29        0.21
# LassoLarsIC                                  0.29       0.31  1.29        0.08
# LassoLarsCV                                  0.29       0.31  1.29        0.23
# LinearSVR                                    0.27       0.30  1.30        0.61
# PoissonRegressor                             0.25       0.28  1.32        0.05
# AdaBoostRegressor                            0.20       0.23  1.36        0.89
# OrthogonalMatchingPursuitCV                  0.20       0.23  1.37        0.08
# OrthogonalMatchingPursuit                    0.20       0.23  1.37        0.12
# TweedieRegressor                             0.19       0.22  1.37        0.06
# GammaRegressor                               0.19       0.22  1.37        0.18
# LarsCV                                       0.13       0.16  1.42        0.20
# ElasticNet                                  -0.04       0.00  1.55        0.04
# DummyRegressor                              -0.04       0.00  1.55        0.03
# LassoLars                                   -0.04       0.00  1.55        0.12
# Lasso                                       -0.04       0.00  1.55        0.04
# QuantileRegressor                           -0.05      -0.01  1.56        1.40
# PassiveAggressiveRegressor                  -0.17      -0.13  1.65        0.07
# RANSACRegressor                             -1.30      -1.21  2.31        0.62
# KernelRidge                                -14.25     -13.70  5.95        0.78
# Lars                                       -14.38     -13.82  5.98        0.06

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                0.46       0.54  1.06        0.72
# RandomForestRegressor                        0.44       0.52  1.08        4.93
# LGBMRegressor                                0.44       0.52  1.08        0.19
# XGBRegressor                                 0.44       0.52  1.08        2.46
# BaggingRegressor                             0.41       0.49  1.11        0.53
# NuSVR                                        0.39       0.48  1.12        1.03
# SVR                                          0.39       0.48  1.12        1.50
# KNeighborsRegressor                          0.38       0.47  1.13        0.05
# MLPRegressor                                 0.36       0.45  1.15        3.44
# GradientBoostingRegressor                    0.33       0.42  1.18        1.87
# ExtraTreesRegressor                          0.22       0.34  1.27        7.08
# DecisionTreeRegressor                        0.20       0.32  1.28        0.10
# Ridge                                        0.20       0.32  1.28        0.04
# LinearRegression                             0.20       0.32  1.28        0.03
# TransformedTargetRegressor                   0.20       0.32  1.28        0.16
# RidgeCV                                      0.20       0.32  1.28        0.05
# ElasticNetCV                                 0.20       0.32  1.28        2.02
# LassoCV                                      0.20       0.32  1.28        2.13
# ExtraTreeRegressor                           0.20       0.32  1.29        0.15
# SGDRegressor                                 0.19       0.31  1.29        0.08
# BayesianRidge                                0.19       0.31  1.29        0.15
# LassoLarsCV                                  0.19       0.31  1.29        0.21
# LassoLarsIC                                  0.19       0.31  1.29        0.08
# HuberRegressor                               0.19       0.31  1.29        0.18
# LinearSVR                                    0.16       0.28  1.32        0.58
# PoissonRegressor                             0.16       0.28  1.32        0.04
# OrthogonalMatchingPursuit                    0.11       0.24  1.36        0.13
# OrthogonalMatchingPursuitCV                  0.11       0.24  1.36        0.08
# GammaRegressor                               0.08       0.22  1.37        0.15
# TweedieRegressor                             0.08       0.22  1.38        0.04
# AdaBoostRegressor                            0.07       0.21  1.38        0.76
# LarsCV                                       0.02       0.16  1.42        0.19
# DummyRegressor                              -0.17      -0.00  1.55        0.03
# ElasticNet                                  -0.17      -0.00  1.55        0.03
# LassoLars                                   -0.17      -0.00  1.55        0.10
# Lasso                                       -0.17      -0.00  1.55        0.03
# QuantileRegressor                           -0.19      -0.02  1.57        1.33
# PassiveAggressiveRegressor                  -0.42      -0.22  1.71        0.06
# RANSACRegressor                             -1.56      -1.19  2.30        0.52
# GaussianProcessRegressor                    -6.02      -4.99  3.80        2.79
# KernelRidge                                -16.36     -13.82  5.98        0.68
# Lars                                       -23.48     -19.91  7.10        0.05

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
