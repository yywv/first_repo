# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: chembl_webresource_client in c:\users\rayhan\appdata\roaming\python\python313\site-packages (0.10.9)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from chembl_webresource_client) (2.3.0)
# Requirement already satisfied: requests>=2.18.4 in c:\programdata\anaconda3\lib\site-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in c:\users\rayhan\appdata\roaming\python\python313\site-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in c:\users\rayhan\appdata\roaming\python\python313\site-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: attrs>=21.2 in c:\users\rayhan\appdata\roaming\python\python313\site-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\rayhan\appdata\roaming\python\python313\site-packages (from requests-cache~=1.2->chembl_webresource_client) (25.3.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.7)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\rayhan\appdata\roaming\python\python313\site-packages (from requests-cache~=1.2->chembl_webresource_client) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\users\rayhan\appdata\roaming\python\python313\site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2025.4.26)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                   organism  \
# 0                []    Drosophila melanogaster
# 1                []               Homo sapiens
# 2                []        Torpedo californica
# 3                []               Mus musculus
# 4                []          Rattus norvegicus
# 5                []   Electrophorus electricus
# 6                []                 Bos taurus
# 7                []          Anopheles gambiae
# 8                []             Bemisia tabaci
# 9                []  Leptinotarsa decemlineata
# 10               []     Nephotettix cincticeps
# 11               []              Gallus gallus
# 12               []                Danio rerio
# 13               []              Aedes aegypti
# 14               []               Homo sapiens
# 15               []            Musca domestica
# 16               []        Plutella xylostella
# 17               []            Musca domestica
# 18               []  Pediculus humanus capitis
# 19               []          Spodoptera litura
# 20               []      Laodelphax striatella
# 21               []        Schizaphis graminum
# 22               []               Homo sapiens
# 23               []          Rattus norvegicus
# 24               []     Caenorhabditis elegans
# 25               []             Equus caballus
# 26               []             Equus caballus
# 27               []     Canis lupus familiaris
# 28               []               Mus musculus
# 29               []          Rattus norvegicus
# 30               []               Homo sapiens
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   18.0
# 1                                Acetylcholinesterase   16.0
# 2                                Acetylcholinesterase   16.0
# 3                                Acetylcholinesterase   16.0
# 4                                Acetylcholinesterase   16.0
# 5                                Acetylcholinesterase   16.0
# 6                                Acetylcholinesterase   16.0
# 7                                Acetylcholinesterase   16.0
# 8                                               AChE2   16.0
# 9                                Acetylcholinesterase   16.0
# 10               Ace-orthologous acetylcholinesterase   16.0
# 11                               Acetylcholinesterase   16.0
# 12                               Acetylcholinesterase   16.0
# 13                               Acetylcholinesterase   16.0
# 14                                       Protein CutA   16.0
# 15                               Acetylcholinesterase   15.0
# 16                               Acetylcholinesterase   15.0
# 17                               Acetylcholinesterase   15.0
# 18                               Acetylcholinesterase   15.0
# 19                               Acetylcholinesterase   15.0
# 20                               Acetylcholinesterase   15.0
# 21                               Acetylcholinesterase   15.0
# 22                       Cholinesterases; ACHE & BCHE   14.0
# 23  Acetylcholinesterase and butyrylcholinesterase...   14.0
# 24                             Acetylcholinesterase 1   14.0
# 25                              Butyrylcholinesterase   11.0
# 26                                     Cholinesterase   11.0
# 27                                     Cholinesterase   11.0
# 28                                     Cholinesterase   10.0
# 29                              Butyrylcholinesterase   10.0
# 30                                     Cholinesterase    5.0
#
#     species_group_flag target_chembl_id  \
# 0                False    CHEMBL2242744
# 1                False        CHEMBL220
# 2                False       CHEMBL4780
# 3                False       CHEMBL3198
# 4                False       CHEMBL3199
# 5                False       CHEMBL4078
# 6                False       CHEMBL4768
# 7                False    CHEMBL2046266
# 8                False    CHEMBL2366409
# 9                False    CHEMBL2366490
# 10               False    CHEMBL2366514
# 11               False    CHEMBL3227914
# 12               False    CHEMBL3308995
# 13               False    CHEMBL4295607
# 14               False    CHEMBL6067022
# 15               False       CHEMBL5752
# 16               False    CHEMBL2242729
# 17               False    CHEMBL2242743
# 18               False    CHEMBL2362988
# 19               False    CHEMBL2366422
# 20               False    CHEMBL2366446
# 21               False    CHEMBL2366511
# 22               False    CHEMBL2095233
# 23               False    CHEMBL2111475
# 24               False    CHEMBL3341583
# 25               False       CHEMBL5077
# 26               False       CHEMBL5763
# 27               False    CHEMBL4630814
# 28               False       CHEMBL2528
# 29               False       CHEMBL3403
# 30               False       CHEMBL1914
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 2   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'O60888', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 17  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 23  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
# 24  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
# 25  [{'accession': 'Q9N1N9', 'component_descriptio...     SINGLE PROTEIN
# 26  [{'accession': 'P81908', 'component_descriptio...     SINGLE PROTEIN
# 27  [{'accession': 'P32750', 'component_descriptio...     SINGLE PROTEIN
# 28  [{'accession': 'Q03311', 'component_descriptio...     SINGLE PROTEIN
# 29  [{'accession': 'Q9JKC1', 'component_descriptio...     SINGLE PROTEIN
# 30  [{'accession': 'P06276', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     7227
# 1     9606
# 2     7787
# 3    10090
# 4    10116
# 5     8005
# 6     9913
# 7     7165
# 8     7038
# 9     7539
# 10   94400
# 11    9031
# 12    7955
# 13    7159
# 14    9606
# 15    7370
# 16   51655
# 17    7370
# 18  121226
# 19   69820
# 20  195883
# 21   13262
# 22    9606
# 23   10116
# 24    6239
# 25    9796
# 26    9796
# 27    9615
# 28   10090
# 29   10116
# 30    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2242744'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None     12438748                  []
# 1         None             None     12438749                  []
# 2         None             None     12438750                  []
# 3         None             None     12438751                  []
# 4         None             None     12438752                  []
# 5         None             None     12438753                  []
# 6         None             None     12438754                  []
# 7         None             None     12438755                  []
# 8         None             None     12438756                  []
# 9         None             None     12438757                  []
# 10        None             None     12438758                  []
# 11        None             None     12438759                  []
# 12        None             None     12438760                  []
# 13        None             None     12438761                  []
# 14        None             None     12438762                  []
# 15        None             None     12438763                  []
# 16        None             None     12438764                  []
# 17        None             None     12438765                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 1    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 2    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 3    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 4    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 5    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 6    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 7    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 8    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 9    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 10   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 11   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 12   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 13   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 14   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 15   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 16   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 17   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# 5           B                    None                   None  BAO_0000190
# 6           B                    None                   None  BAO_0000190
# 7           B                    None                   None  BAO_0000190
# 8           B                    None                   None  BAO_0000190
# 9           B                    None                   None  BAO_0000190
# 10          B                    None                   None  BAO_0000190
# 11          B                    None                   None  BAO_0000190
# 12          B                    None                   None  BAO_0000190
# 13          B                    None                   None  BAO_0000190
# 14          B                    None                   None  BAO_0000190
# 15          B                    None                   None  BAO_0000190
# 16          B                    None                   None  BAO_0000190
# 17          B                    None                   None  BAO_0000190
#
#     ...          target_organism      target_pref_name target_tax_id  \
# 0   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 1   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 2   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 3   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 4   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 5   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 6   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 7   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 8   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 9   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 10  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 11  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 12  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 13  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 14  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 15  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 16  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 17  ...  Drosophila melanogaster  Acetylcholinesterase          7227
#
#    text_value  toid  type units    uo_units upper_value    value
# 0        None  None  IC50    uM  UO_0000065        None     1.83
# 1        None  None  IC50    uM  UO_0000065        None   112.72
# 2        None  None  IC50    uM  UO_0000065        None     37.5
# 3        None  None  IC50    uM  UO_0000065        None      4.5
# 4        None  None  IC50    uM  UO_0000065        None     1.84
# 5        None  None  IC50    uM  UO_0000065        None     3.81
# 6        None  None  IC50    uM  UO_0000065        None    12.34
# 7        None  None  IC50    uM  UO_0000065        None     9.92
# 8        None  None  IC50    uM  UO_0000065        None     8.29
# 9        None  None  IC50    uM  UO_0000065        None     1.76
# 10       None  None  IC50    uM  UO_0000065        None     1.43
# 11       None  None  IC50    uM  UO_0000065        None     4.84
# 12       None  None  IC50    uM  UO_0000065        None     10.2
# 13       None  None  IC50    uM  UO_0000065        None     0.87
# 14       None  None  IC50    uM  UO_0000065        None    12.34
# 15       None  None  IC50    uM  UO_0000065        None     8.07
# 16       None  None  IC50    uM  UO_0000065        None     1.64
# 17       None  None  IC50    uM  UO_0000065        None  40000.0
#
# [18 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None     12438748                  []
# 1         None             None     12438749                  []
# 2         None             None     12438750                  []
# 3         None             None     12438751                  []
# 4         None             None     12438752                  []
# 5         None             None     12438753                  []
# 6         None             None     12438754                  []
# 7         None             None     12438755                  []
# 8         None             None     12438756                  []
# 9         None             None     12438757                  []
# 10        None             None     12438758                  []
# 11        None             None     12438759                  []
# 12        None             None     12438760                  []
# 13        None             None     12438761                  []
# 14        None             None     12438762                  []
# 15        None             None     12438763                  []
# 16        None             None     12438764                  []
# 17        None             None     12438765                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 1    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 2    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 3    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 4    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 5    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 6    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 7    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 8    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 9    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 10   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 11   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 12   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 13   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 14   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 15   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 16   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 17   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# 5           B                    None                   None  BAO_0000190
# 6           B                    None                   None  BAO_0000190
# 7           B                    None                   None  BAO_0000190
# 8           B                    None                   None  BAO_0000190
# 9           B                    None                   None  BAO_0000190
# 10          B                    None                   None  BAO_0000190
# 11          B                    None                   None  BAO_0000190
# 12          B                    None                   None  BAO_0000190
# 13          B                    None                   None  BAO_0000190
# 14          B                    None                   None  BAO_0000190
# 15          B                    None                   None  BAO_0000190
# 16          B                    None                   None  BAO_0000190
# 17          B                    None                   None  BAO_0000190
#
#     ...          target_organism      target_pref_name target_tax_id  \
# 0   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 1   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 2   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 3   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 4   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 5   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 6   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 7   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 8   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 9   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 10  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 11  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 12  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 13  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 14  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 15  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 16  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 17  ...  Drosophila melanogaster  Acetylcholinesterase          7227
#
#    text_value  toid  type units    uo_units upper_value    value
# 0        None  None  IC50    uM  UO_0000065        None     1.83
# 1        None  None  IC50    uM  UO_0000065        None   112.72
# 2        None  None  IC50    uM  UO_0000065        None     37.5
# 3        None  None  IC50    uM  UO_0000065        None      4.5
# 4        None  None  IC50    uM  UO_0000065        None     1.84
# 5        None  None  IC50    uM  UO_0000065        None     3.81
# 6        None  None  IC50    uM  UO_0000065        None    12.34
# 7        None  None  IC50    uM  UO_0000065        None     9.92
# 8        None  None  IC50    uM  UO_0000065        None     8.29
# 9        None  None  IC50    uM  UO_0000065        None     1.76
# 10       None  None  IC50    uM  UO_0000065        None     1.43
# 11       None  None  IC50    uM  UO_0000065        None     4.84
# 12       None  None  IC50    uM  UO_0000065        None     10.2
# 13       None  None  IC50    uM  UO_0000065        None     0.87
# 14       None  None  IC50    uM  UO_0000065        None    12.34
# 15       None  None  IC50    uM  UO_0000065        None     8.07
# 16       None  None  IC50    uM  UO_0000065        None     1.64
# 17       None  None  IC50    uM  UO_0000065        None  40000.0
#
# [18 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 18

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None     12438748                  []
# 1         None             None     12438749                  []
# 2         None             None     12438750                  []
# 3         None             None     12438751                  []
# 4         None             None     12438752                  []
# 5         None             None     12438753                  []
# 6         None             None     12438754                  []
# 7         None             None     12438755                  []
# 8         None             None     12438756                  []
# 9         None             None     12438757                  []
# 10        None             None     12438758                  []
# 11        None             None     12438759                  []
# 12        None             None     12438760                  []
# 13        None             None     12438761                  []
# 14        None             None     12438762                  []
# 15        None             None     12438763                  []
# 16        None             None     12438764                  []
# 17        None             None     12438765                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 1    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 2    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 3    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 4    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 5    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 6    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 7    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 8    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 9    CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 10   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 11   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 12   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 13   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 14   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 15   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 16   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
# 17   CHEMBL3068296  Inhibition of acetylcholinesterase in Drosophi...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# 5           B                    None                   None  BAO_0000190
# 6           B                    None                   None  BAO_0000190
# 7           B                    None                   None  BAO_0000190
# 8           B                    None                   None  BAO_0000190
# 9           B                    None                   None  BAO_0000190
# 10          B                    None                   None  BAO_0000190
# 11          B                    None                   None  BAO_0000190
# 12          B                    None                   None  BAO_0000190
# 13          B                    None                   None  BAO_0000190
# 14          B                    None                   None  BAO_0000190
# 15          B                    None                   None  BAO_0000190
# 16          B                    None                   None  BAO_0000190
# 17          B                    None                   None  BAO_0000190
#
#     ...          target_organism      target_pref_name target_tax_id  \
# 0   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 1   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 2   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 3   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 4   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 5   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 6   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 7   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 8   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 9   ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 10  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 11  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 12  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 13  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 14  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 15  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 16  ...  Drosophila melanogaster  Acetylcholinesterase          7227
# 17  ...  Drosophila melanogaster  Acetylcholinesterase          7227
#
#    text_value  toid  type units    uo_units upper_value    value
# 0        None  None  IC50    uM  UO_0000065        None     1.83
# 1        None  None  IC50    uM  UO_0000065        None   112.72
# 2        None  None  IC50    uM  UO_0000065        None     37.5
# 3        None  None  IC50    uM  UO_0000065        None      4.5
# 4        None  None  IC50    uM  UO_0000065        None     1.84
# 5        None  None  IC50    uM  UO_0000065        None     3.81
# 6        None  None  IC50    uM  UO_0000065        None    12.34
# 7        None  None  IC50    uM  UO_0000065        None     9.92
# 8        None  None  IC50    uM  UO_0000065        None     8.29
# 9        None  None  IC50    uM  UO_0000065        None     1.76
# 10       None  None  IC50    uM  UO_0000065        None     1.43
# 11       None  None  IC50    uM  UO_0000065        None     4.84
# 12       None  None  IC50    uM  UO_0000065        None     10.2
# 13       None  None  IC50    uM  UO_0000065        None     0.87
# 14       None  None  IC50    uM  UO_0000065        None    12.34
# 15       None  None  IC50    uM  UO_0000065        None     8.07
# 16       None  None  IC50    uM  UO_0000065        None     1.64
# 17       None  None  IC50    uM  UO_0000065        None  40000.0
#
# [18 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#    molecule_chembl_id                             canonical_smiles  \
# 0        CHEMBL463210             CCOP(=S)(OCC)Oc1nc(Cl)c(Cl)cc1Cl
# 1       CHEMBL2252723  CCOP(=O)(OCC)SCCCCCCCCCCN1C(=O)c2ccccc2C1=O
# 2       CHEMBL2252722   CCOP(=O)(OCC)SCCCCCCCCCN1C(=O)c2ccccc2C1=O
# 3       CHEMBL2252721    CCOP(=O)(OCC)SCCCCCCCCN1C(=O)c2ccccc2C1=O
# 4       CHEMBL2252851     CCOP(=O)(OCC)SCCCCCCCN1C(=O)c2ccccc2C1=O
# 5       CHEMBL2252850      CCOP(=O)(OCC)SCCCCCCN1C(=O)c2ccccc2C1=O
# 6       CHEMBL2252849       CCOP(=O)(OCC)SCCCCCN1C(=O)c2ccccc2C1=O
# 7       CHEMBL2252848        CCOP(=O)(OCC)SCCCCN1C(=O)c2ccccc2C1=O
# 8       CHEMBL2252847         CCOP(=O)(OCC)SCCCN1C(=O)c2ccccc2C1=O
# 9       CHEMBL2252846       CCOP(=O)(OCC)SCCCCCCCCCCSP(=O)(OCC)OCC
# 10      CHEMBL2252845        CCOP(=O)(OCC)SCCCCCCCCCSP(=O)(OCC)OCC
# 11      CHEMBL2252844         CCOP(=O)(OCC)SCCCCCCCCSP(=O)(OCC)OCC
# 12      CHEMBL2252843          CCOP(=O)(OCC)SCCCCCCCSP(=O)(OCC)OCC
# 13      CHEMBL2252842           CCOP(=O)(OCC)SCCCCCCSP(=O)(OCC)OCC
# 14      CHEMBL2252841            CCOP(=O)(OCC)SCCCCCSP(=O)(OCC)OCC
# 15      CHEMBL2252840             CCOP(=O)(OCC)SCCCCSP(=O)(OCC)OCC
# 16      CHEMBL2252724              CCOP(=O)(OCC)SCCCSP(=O)(OCC)OCC
# 17      CHEMBL1232328                               CCOP(O)(=S)OCC
#
#    standard_value
# 0          1830.0
# 1        112720.0
# 2         37500.0
# 3          4500.0
# 4          1840.0
# 5          3810.0
# 6         12340.0
# 7          9920.0
# 8          8290.0
# 9          1760.0
# 10         1430.0
# 11         4840.0
# 12        10200.0
# 13          870.0
# 14        12340.0
# 15         8070.0
# 16         1640.0
# 17     40000000.0

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#    molecule_chembl_id                             canonical_smiles  \
# 0        CHEMBL463210             CCOP(=S)(OCC)Oc1nc(Cl)c(Cl)cc1Cl
# 1       CHEMBL2252723  CCOP(=O)(OCC)SCCCCCCCCCCN1C(=O)c2ccccc2C1=O
# 2       CHEMBL2252722   CCOP(=O)(OCC)SCCCCCCCCCN1C(=O)c2ccccc2C1=O
# 3       CHEMBL2252721    CCOP(=O)(OCC)SCCCCCCCCN1C(=O)c2ccccc2C1=O
# 4       CHEMBL2252851     CCOP(=O)(OCC)SCCCCCCCN1C(=O)c2ccccc2C1=O
# 5       CHEMBL2252850      CCOP(=O)(OCC)SCCCCCCN1C(=O)c2ccccc2C1=O
# 6       CHEMBL2252849       CCOP(=O)(OCC)SCCCCCN1C(=O)c2ccccc2C1=O
# 7       CHEMBL2252848        CCOP(=O)(OCC)SCCCCN1C(=O)c2ccccc2C1=O
# 8       CHEMBL2252847         CCOP(=O)(OCC)SCCCN1C(=O)c2ccccc2C1=O
# 9       CHEMBL2252846       CCOP(=O)(OCC)SCCCCCCCCCCSP(=O)(OCC)OCC
# 10      CHEMBL2252845        CCOP(=O)(OCC)SCCCCCCCCCSP(=O)(OCC)OCC
# 11      CHEMBL2252844         CCOP(=O)(OCC)SCCCCCCCCSP(=O)(OCC)OCC
# 12      CHEMBL2252843          CCOP(=O)(OCC)SCCCCCCCSP(=O)(OCC)OCC
# 13      CHEMBL2252842           CCOP(=O)(OCC)SCCCCCCSP(=O)(OCC)OCC
# 14      CHEMBL2252841            CCOP(=O)(OCC)SCCCCCSP(=O)(OCC)OCC
# 15      CHEMBL2252840             CCOP(=O)(OCC)SCCCCSP(=O)(OCC)OCC
# 16      CHEMBL2252724              CCOP(=O)(OCC)SCCCSP(=O)(OCC)OCC
# 17      CHEMBL1232328                               CCOP(O)(=S)OCC
#
#     standard_value         class
# 0           1830.0  intermediate
# 1         112720.0      inactive
# 2          37500.0      inactive
# 3           4500.0  intermediate
# 4           1840.0  intermediate
# 5           3810.0  intermediate
# 6          12340.0      inactive
# 7           9920.0  intermediate
# 8           8290.0  intermediate
# 9           1760.0  intermediate
# 10          1430.0  intermediate
# 11          4840.0  intermediate
# 12         10200.0      inactive
# 13           870.0        active
# 14         12340.0      inactive
# 15          8070.0  intermediate
# 16          1640.0  intermediate
# 17      40000000.0      inactive

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: mannwhitneyu_LogP.csv (deflated 11%)
#   adding: mannwhitneyu_MW.csv (deflated 6%)
#   adding: mannwhitneyu_NumHAcceptors.csv (deflated 10%)
#   adding: mannwhitneyu_NumHDonors.csv (deflated 8%)
#   adding: mannwhitneyu_pIC50.csv (deflated 9%)

# %%
! ls
# Out:
# acetylcholinesterase.zip
# CDD_ML_Part_1_Acetylcholinesterase_Bioactivity_Data_Concised.ipynb
# CDD_ML_Part_2_Acetylcholinesterase_Exploratory_Data_Analysis.ipynb
# CDD_ML_Part_3_Acetylcholinesterase_Descriptor_Dataset_Preparation.ipynb
# mannwhitneyu_LogP.csv
# mannwhitneyu_MW.csv
# mannwhitneyu_NumHAcceptors.csv
# mannwhitneyu_NumHDonors.csv
# mannwhitneyu_pIC50.csv
# molecule.smi
# plot_bioactivity_class.pdf
# plot_ic50.pdf
# plot_LogP.pdf
# plot_MW.pdf
# plot_MW_vs_LogP.pdf
# plot_NumHAcceptors.pdf
# plot_NumHDonors.pdf
